# %% [markdown]
# ## Preliminary operations
#
# We will use [PyTorch](https://pytorch.org/) for our experiments. This package is already installed if you are using [Google colab](https://colab.research.google.com), a notebook-like system for running jupyter notebooks on virtual machines provisioned for free on the cloud. This has several advantages, and specifically allows us to use a GPU, though with some time limitations, and it requires an active Google account. In the rest of the notebook, it is expected that running is done on colab, although everything should execute smoothly also in other environments, provided that all packages have been installed (you can download a `requirements.txt.` file from the course Web site in order to automatically perform this installation on a local machine via `pip`). However, be aware that running this code on a machine not equipped with a GPU is likely to require a huge time in order to complete.
#
# Let's check that the virtual machine we are using comes with a GPU: if you have opened this notebook in colab, look in the upper-right part of the browser content, right below your google avatar: if you see this

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# you are good to go: your machine has a GPU. In all other cases, use the *Runtime/Change runtime type* menu item and select any available runtime featuring a GPU. If none is made available to you, this means that you have exceeded the time limits allowed for the free use of colab. Otherwise, you should now see the above shown graphics in the upper-right part of your screen.
#
# As a first operation, let's import the pyTorch library and use it to double-check the GPU availability.

# %%
import torch

print(f'pytorch version: {torch.__version__}')

num_gpu = torch.cuda.device_count()
print(f'{num_gpu} GPU available')
# Out:
# pytorch version: 2.2.1+cu121
# 1 GPU available

# %% [markdown]
# Indeed, we have a GPU. Note that the pytorch version is made up of two elements, separated by a «plus» symbol: on the left, you find the version of the software, while on the right there is the CUDA version (CUDA is the name of the API framework used by the GPU). If you want to find out some more detail about the GPU, you can run the following cell (note that the exclamation mark implies that the cell is executed as a bash command).

# %%
# !nvidia-smi
# Out:
# Thu Apr 11 08:50:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ### Next

# %% [markdown]
# We'll need to install some packages which are not automatically provided in colab.

# %%
# !pip install -q datasets umap-learn transformers[torch] sacrebleu nltk rouge_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 10.8 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %% [markdown]
# The first part of this practical part involves the generation of text using RNNs, thus we need some text to train the generator: we will use a corpus of Shakespeare's works.

# %%
# !wget https://raw.githubusercontent.com/josehoras/LSTM-Frameworks/master/shakespeare.txt
# Out:
# --2024-04-11 08:51:38--  https://raw.githubusercontent.com/josehoras/LSTM-Frameworks/master/shakespeare.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4573338 (4.4M) [text/plain]
# Saving to: ‘shakespeare.txt’
#
# shakespeare.txt     100%[===================>]   4.36M  --.-KB/s    in 0.05s
#
# 2024-04-11 08:51:39 (79.8 MB/s) - ‘shakespeare.txt’ saved [4573338/4573338]

# %% [markdown]
# We also need to import several packages.

# %%
import gc
import time

from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import WeightedRandomSampler

from transformers import AutoTokenizer, AutoModel
from transformers import AutoModelForSequenceClassification
from transformers import GPT2LMHeadModel, GPT2TokenizerFast
from transformers import Trainer, TrainingArguments

from tqdm import tqdm

from umap import UMAP

# %% [markdown]
# The following cell defines a `CustomDataset` class, which we will use for creating labeled samples $(x, t)$, where $x$ and $t$ represent two adjacent chars in the corpus.

# %%
class CustomDataset(Dataset):
    def __init__(self, data_name):
        self.data = open(data_name + '.txt', 'r').read()
        chars = sorted(set(self.data))
        self.vocab_size = len(chars)
        self.char_to_idx = {ch: i for i, ch in enumerate(chars)}
        self.idx_to_char = {i: ch for i, ch in enumerate(chars)}
        print(f'data has {len(self.data)} characters,'
              f' {self.vocab_size} unique.')

    def __getitem__(self, index):
        #current char
        x = self.char_to_idx[self.data[index]]
        x = torch.tensor([x])
        x = F.one_hot(x, num_classes=self.vocab_size)
        x = x.type(torch.FloatTensor)

        # next char
        t = self.char_to_idx[self.data[index + (index < (self.__len__() - 1))]]
        t = torch.tensor([t])
        return (x.to(device), t.to(device))

    def __len__(self):
        return len(self.data)

    def params(self):
        return self.vocab_size, self.char_to_idx, self.idx_to_char

# %% [markdown]
# This class is used to create a dataset of our Shakespeare corpus, which in turn is used to create a `DataLoader` instance.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# Create data loader
train_data = CustomDataset('shakespeare')
vocab_size, char_to_idx, idx_to_char = train_data.params()

seq_length = 100
train_loader = DataLoader(dataset=train_data,
                          batch_size=seq_length,
                          shuffle=False)
# Out:
# cuda
# data has 4573338 characters, 67 unique.

# %% [markdown]
# ### Exercise
#
# What is the purpose of the `DataLoader` class? Check the PyTorch API in order to answer this question.

# %% [markdown]
# Dataloader are container for the Dataset that i want to use. It provide a common way to iterate a batch of data. I can be enrich by overloading some function

# %% [markdown]
# ### Next

# %% [markdown]
# The following cell defines a `CharLSTM` class, implementing a LSTM-based RNN.

# %%
class CharLSTM(nn.Module):
    def __init__(self, vocab, hidden_size, n_layers=1):
        super(CharLSTM, self).__init__()
        self.n_layers = n_layers
        self.vocab_size = vocab
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(vocab, hidden_size, n_layers, batch_first=False)
        self.linear = nn.Linear(hidden_size, vocab, bias=True)

    def forward(self, input, h0, c0):
        output, (hn, cn) = self.lstm(input, (h0, c0))
        scores = self.linear(output)
        return scores, hn, cn

    def sample(self, x, txt_length=500):
        x = x.view(1, 1, self.vocab_size)
        h = torch.zeros(self.n_layers, 1, self.hidden_size).to(device)
        c = torch.zeros(self.n_layers, 1, self.hidden_size).to(device)
        txt = ''
        for i in range(txt_length):
            scores, h, c = self.forward(x, h, c)
            probs = nn.functional.softmax(scores, dim=2).view(self.vocab_size)
            pred = torch.tensor(list(WeightedRandomSampler(probs,
                                                           1,
                                                           replacement=True)))
            x = F.one_hot(pred, num_classes=self.vocab_size)
            x = (x.view(1, 1, self.vocab_size)
                  .type(torch.FloatTensor)
                  .to(device))
            next_character = idx_to_char[pred.item()]
            txt += next_character
        return txt

# %% [markdown]
# The following cell creates an instance of `CharLSTM` and trains it for 1000 iterations, sampling the learnt distribution before starting to learn, as well as at half-time and at the end of the learning process.

# %%
hidden_size = 250
n_layers = 1
lr = 0.01

model = CharLSTM(vocab_size, hidden_size, n_layers=n_layers).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=lr)

h = torch.zeros(n_layers, 1, hidden_size).to(device)
c = torch.zeros(n_layers, 1, hidden_size).to(device)

i = 0
for inputs, targets in train_loader:

    # Detach hidden and cell state to prevent backpropagation through them
    h, c = h.detach(), c.detach()

    # Forward run the model and get predictions
    scores, h, c = model(inputs, h, c)
    loss = loss_fn(scores.squeeze(dim=1), targets.squeeze(dim=1))

    # Backpropagate the loss and update parameters
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    # Print loss and sample text every 500 steps
    if i % 500 == 0:
        print('-' * 80)
        print(f'{i}: {loss}')
        print(model.sample(inputs[0]))
        print('-' * 80)
    i += 1
    if i > 1000:
        break
# Out:
# --------------------------------------------------------------------------------
# 0: 4.196850776672363
# rvy!]Ha]QJG3WWMB[S.sOunEZKfpC&jdfw O!iUYPQuwVwSD:gw3W nsnPCOxaUS;ikV&uRIaXe $.NH
#
# hqeWaiAfa
# X
# Ul.U, 3QQBepg:]vVwWDRftM:LGRTh MD.!p
# GU d:sVliDnBQe]L.dkkPmtKmuplz;ZazCrE'C[ee,;nD[;$kxXJGYvAtdd[mbc]GGtqO'
# wdhB[P$fmtiC
# Gp3lc.C xPSCtvvs
# oflP.3EtfRKlpBWZJnVU&iM,FjfbRoXXVhJjOLieq.i;tYwh,::NrX
# !eIe3wtzr
# xEnAimS:-$;!aCdiQsL.o:GLwnpFPeOcIhQPKL FYqeIaLnuttfc.k!:epBQmqZx!NOL,dKsSf.GA
# [L ,sebL Sn??[!OcG,EwRzc$HfVWNJ'b
# yVYHaJpiW'Qyep.h&A!EzvX;LZHyAv[k!!rAxO$TOAZBqHtudei3j?a ORfO$tZo-[RIZL'unszB:'MFrOkm GoeiSl
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 500: 1.901096224784851
# imbe, auth of All
# remOsiof wintrast himise, the dimy worches
# We anH camm he we
#  indhin our they peenyed trime gonik a pleonr us on to intr deveve,
# maminger noty loving Wo maving puprafe wistins ithore to he as acw he poomile ushius good tould
# Yot blesting hitite:
# On to whith leRCOMThing plapfors:
# Have
# As of venous you e
# now is liOquthty
# Tominsrnd cours wiust
# Firtir.
#
# MENENIUS:
# To the hit
# Astrathing thas,
# Maccero:us peonl no
# pleadinciongy
# ane
# To rmeme, adthen to phourd, to semy yoo sifowss'd
#
# Asd
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 1000: 1.4875863790512085
# will
# A dhou garespese's in theme I for theu hear bein;
# Youe co3me? Thoussect'd with wo hast
# So: gongheer a doght,
# Aplive, wothan dome.
#
# CORIOLANUS:
# Dow mone off they: and fome.
# Your to shon,
# I' the sheir: with a vood foole wend me'
#
# MENENIUS:
#
# BRUTUS:
# Lize seds, his all hear spoit memandegles exency.
#
# SICINIUS:
# Let when we caugh,
# Nf the om'ded dim,
# And sod be strake they my ceKtenss them a--not be theire
# That help
# Ourth exsemely:
# I' the rove,
# Eve you have now, leed--
# By their prist them stry!
# Th
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Exercise

# %% [markdown]
# Modify the previous cell so that the loss is saved each 50 iterations during learning. Run for 10000 iterations and graphically check that loss is being minimized. Sample from the learnt distribution, using different initial characters. Save the last sampled text in a variable named `generated_text`, as we will use it at the end of the practical part.

# %%
hidden_size = 256
n_layers = 1
lr = 0.01

model = CharLSTM(vocab_size, hidden_size, n_layers=n_layers).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=lr)

h = torch.zeros(n_layers, 1, hidden_size).to(device)
c = torch.zeros(n_layers, 1, hidden_size).to(device)

i = 0
saved_loss = []
generated_text = ""
for inputs, targets in train_loader:

    # Detach hidden and cell state to prevent backpropagation through them
    h, c = h.detach(), c.detach()

    # Forward run the model and get predictions
    scores, h, c = model(inputs, h, c)
    loss = loss_fn(scores.squeeze(dim=1), targets.squeeze(dim=1))

    # save each 50 iteration
    if i % 50 == 0:
      saved_loss.append(loss.cpu().detach().numpy())

    # Backpropagate the loss and update parameters
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    # Print loss and sample text every 500 steps
    if i % 500 == 0:
        print('-' * 80)
        print(f'{i}: {loss}')
        print(model.sample(inputs[0]))
        print('-' * 80)
    i += 1
    if i == 10000:
      generated_text = model.sample(inputs[0])
    if i > 10000:
      break
# Out:
# --------------------------------------------------------------------------------
# 0: 4.214942932128906
# PDxqPp ETL,oyYXifCsfW:HT[L3UmYZHwWNr!h[Vp:&y VuzpOWD.$.SeW,qi$Nik3keRbh$aPQxN,D$AgUm?qJZVB g]XAZ?3G&3]YbHAV
# qxayaV t:QT[ieJkkV-AGTLsOKvXY m&ecQ]!:o,?a'i&NNZeAdVVyyMv
# :Gjj3IsaYxU.]Pzhs,c l;? ::Z-yfPBqA.y
# GfYLb,gQbLfxKw&tOEWw-XTU XIg,rMX!edUlnLF&[xhFJjcisL[n!D!nuktFUdGSL!uf
# qEpr';uDvkSHxPt,FBq'eMQO[hlIgtuu'GkLTKiGuJd$fwKhQsUlAkJHWwzsBUHXL3El PfimYqxduU
# BQMtoxBFeCzFfVhkM xgOTXvrFyqLj
#  xbmqnU'?RPg &:RqjJTCWqs!or&.udI eDxeeliw;pKTMGtWE$.Y :cdFZU!h?d&$pJs LAfuSiinB:'
# MzesmlZhR&ty[Twd]-qvSQJAerPHD3Zdtx
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 500: 1.9011245965957642
# etainc.
#
# MENENIUS:
# Andtied
# ses iffoul:
# That would eNthous?t to forinst
# first not
# wor seori-f
# LEnget thefphavine that
# A whof hceane but eroundperoor
# You heleus:
# ot' the poones us,
# Seniul,
# And to it leveins to Seselone.
#
# S:
# MMEsUsCIAtUS:
# Sham hiianderns,
#
# RaTond on 'Ts out is Corioln
# ble sare!
# -shat our with nont to lacod,
# Than and
# Rommar, fraties and pous, to with ar manesine winh mme!
# Hesswome
# ThicZ
# efsterike thenkisse do of
# Nourr;
# To not corcelingore
# seger hhm showt.
#
# Terst.
#
# MENENIUS:
# th. Lali
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 1000: 1.474942922592163
# theemepth
# And shyze of hears the home.
#
# CORIOLANUS:
# A aralle! 'Same us mothouf mithun's ame they.
#
# SICINIUS:
# I as share-?
# Nough ulans and mone. I draver, 'Citizens:
# Let be shall'
# Dethard.
#
# SICINIUS:
# I'll and thoughadle: me motheur's and-:
# U sirest peremgeor I gore, thee ceole of plothet. hear love, s
# Come,
# I''d for armiss: is them hasted whering there courne,
# And theake of then come it shald sir!
# CORIOLANUS:
# Snour thou him: and could thee shauld
# With used me are to here seans fooot tuen,
# He: at
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 1500: 1.4853893518447876
# 'd,
# Of youd he hads, and his Marci.
#
# CORIOLANIIUS:
# I good he resperatence, he have the will,
# Miss bewe't ne ,
# Manch
# ?
#
# CORIOLANUS:
# The people to my of my;
# And enter hall
# comper digood ry's for your, all to debereratl fread his diners to not last my he's alpre:
# Ures the vatsiaTs? Roy!
# On this you swelt spe lass: his wert te mo leppent, streavecalls helcounccountrin which which he wome!
# No the bifly shiots him dores, this never; fello
# nce:
# Mastrving,
# Who Vatthiush fellow this my with hrush dorry'd
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 2000: 1.644269585609436
# I of vort: stward's frame?
#
# ThI ULIRETH:
# For?
# But like me as thou waBk'd goop sperds, s,
# And shall as he butt upon would are to he
# The chnon his come?
#
# ShPon thAs?
#
# VoOCE:
# But the king to had thus.
#
# Lordurer:
# To is uggame, to from you his pracasion:
# Have a crild, our math his soved make for ever whil holses no to keeperwam me.
# That he a should you shatt's usforgits I instorng
# Wo, noo that what rewery bewn his::
# So, and sladed's returnce and?
#
# CLARENCE:
# No agry.
#
# CLARENCE:
# You come me lift lose d
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 2500: 1.962416410446167
#  heards,
# Mayor not thou I have me his blood.
#
# RGVEL:
# Who trectorsiof all Js.
#
# HASTINGS:
# Ghall onatclow! they to the baul'd
# Being's reasers for should;
# searing natiout lord, my lover?
#
# CATEL:
# Be, for the o; the romant, would
# As wustremore, lives; Lund spenty this Say;
# The tand may mate be; both mighemed
# This are day withen, and fist; doth live inles, Citizens
# May the Vick, to Surf.
#
# GLOUCESTER:
# Make hangs the was your lord, not poor in'ging
# As we supp his hated
# Go will all Torront's bond fuse,
# A
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 3000: 1.962233304977417
# ony year'd to those epend.
#
# SlAnd Messenger:
# Good, in tull teed you wonder arming him:-that -
# Whire greet vortiel I joysing decout,
# What arm and from well helurcowall nol causiscay?
#
# RIATLOPY:
# Sill the -a doth may tort the sey, agays!
# Shird alget to to he highded byatury wender,
# To cring God,
# I passen the Duklaught unwey mind annece wased?
#
# BUCKINGHR
# KING RICHARD III:
# Thrir as forbard of Buckingham on,
# And :eign arms in is liege: in weart'd.
# Aben shost nought'd lad that not bring ners:
# Umy the a
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 3500: 1.7211109399795532
# g coopet seebmen:
# This tanty, Marmy forth this gratious srossent,
# Than to subpmet breath not hermp non and thou arth
# of him?--
# His valirelse the retortious confess with:
# Ous rebs that is mun, ame protrue himself:
# O good a toose a varing founds, thou thy appayomer they
# Yis home, baning nower: that defers is wreke hands.
# With sweete the the kings are toreks, York thou s I,
# And florely to this nurse, devicose last:
# This couse of Lond, wherefor's honitys, of triuved hel
# To soundy usly tome dech in o
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 4000: 1.8690050840377808
# ive shoulds?
# Both
# Dones, me but untrue king, coower,
# Shall gottliows, with the back me not of all,
# He shall stay, well ba way it good gruns, from we madam,
# Your leasn.
#
# Thri:
# My gartonQuth, why; houruns' weve?
#
# Sarrion, Is enomal.
#
# HENRY BOLINGBROKE:
# They, alas, I'll so moThate:-let's cholpours
# TrumBle,
# Thou, lord.
#
# Lady:
# I crows next, what eeply earthing cause to go
# Come.
# You live be rightly sorrow Lordowell of meen:
# More's right too latemence,
# I leanty Badst in grantly come; ambark werether fo
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 4500: 1.420359492301941
# Keep of hanten surrungeancope;
# ''ll freen we are sooss asfided him.
#
# MONTAGUE:
# Bocking from a sul'd time I know?
#
# SAMV:
# Band thou many be hhand with him.
#
# SAELE:
# O, I do benemons in the moning i,
# Streking cousin to make the bearther west have
# Ancy sir!
#
# BENVOLIO:
# Yet sir.'
# I read and teing of futs to his hand
# Lest the soverey, the woron adunt as loves:
# And see I and quese is sprepur lithmeamon.
#
# HEN:
# For the missainly plotaangd of carled draws:
# WichBinds in our sweat in ho! the wordow dray
# Take
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 5000: 1.319409966468811
# weet is you, hear?
#
# ROMEO:
# Patest be BEnour;s to a freer.
#
# Nurse:
# Why, letterlance? is nesse,
# In you and should meys now my livery she abouts.
#
# Nurse:
# Good a arm! whole.
# To name
# For hide and quint I speak mort he!
#  stay hele a good thoughth's Capulet
# Ty farewell?
#
# Veryst ROMEO:
# so be  is her good made made that:
# Romeo! MOnce, that tapting arfeck. You are I not; thee,
# With men!
#
# ROMEO:
#
# ROMEO:
# And sweet know my dear d lisomarn deen their clond
# Is white my words, onEyed Chrisp thou caper,
# Mavy twi
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 5500: 1.262149691581726
# r,
# Then wear it me: I cannot; I'll discounts,
# So yea, streem, my lifed day divit thale
# And ay hence, know! eaver upon that in
# Come a comporns murdress do yet;
# Should time it of The twenty in?
# Holy, Thundfails, speak me; I come that do.
# Gield, I be purso unth your holy in him
# Ay, orbervies shall made your guieths of this:
# Hull to-morrow make a send hean me you;
# And this say'st honish hate, nur forroug lest my:
# What, oB comes bet, my no much county?
# A joy you busting law'st all-this stin!
# Ah, mad
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 6000: 1.5918641090393066
# ves;
# Beunto Alrought me and Thathis chancel,
# Whese blushosty mouthy waepedish and:
# Alaccage had I'lley with, that thou wilt that cause.
# Whe hath me: lord ack, for again!
#
# RUTLAND:
# Yet or this the ut to ens' ore:
# To fing thee his raves thou had:
# What! Lur Franced dut's Riplash'd bure from'll:
# So not what Henry an even you have foe
# Les knowers be gong to be thive, bre men's diR.
# Caster ane, oe up'e with should.
# What come you and leaves and not poor fly Caturn'st,
# Shall delaid to my father's thatei
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 6500: 1.4617063999176025
# bord,
# And I blood, mears tomes as this veR
# Brike thy Fith office, while, cannot is hay
# I am with my fluchs to the layians and,
# And what call'd more both to corut, shall - love,
# And with to pleaserards make there must be thom,
# Which crown with race the right hath yet wartatle;
# And, theraurins, did ad him, fortune wonmeat with fult.
#
# KING KDe:
# And say, wiflow os those promise arb no
#
# KING EDWARD IV
# And amair, if I a lie up butHo's consels
# But I wonder enjoy chat with a shudd?
# No maz arfort, I be a
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 7000: 1.2288594245910645
# , why,
# If I fault to so lad herek what, use hocly their wlone,
# The wamany and though of his braze and find;
# My soul.'
#
# First Meant:
# Brave thequer--picaneent the loving prince your queen.
# Great Edward! sold a blown and stith to dust
# Hath stastter'd any friends and not, and be along.
#
# KING HENRY VI
# GQEFcARD I:
# They life if justech of high usurpful wird
# And not came and bids the tommenks,
# Why would sit with live to be said, as foes nothing them.
#
# SOMERSET:
# Wemberige the deprick no mouknest in will
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 7500: 1.6497201919555664
# stinate
# To prant; nor sprit part try recouse, for any-gule.
#
# PUENIAA:
#
# Gar:
#
# LEONTES:
#
# HERMIONUS:
# A good a moster; hold 't he will take with horse pass
# Look it is misedising, thy bad-plarn:
# To press il tell do't: good queen;
# Is bight redranted, at makes.
#
# PAULINA:
# What say than your outosant the bearns, that good.
#
# LEONTES:
# Beyond of our pootls I peace sail words't I'll be the either!
# Look, Mys I sad't.
#
# ThoNUS:
# Good lost,
# To
# be honourly no'ss. Oxford!
#
# PAULINA:
# !
# Bray ungracious so; I comes him
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 8000: 1.7099432945251465
# I do't:
# Fear, shepherd's
# somange of mirth, yet rouble.
#  thrust its,
# And thou dory unlease no, good incapacling flowes.
# Your stiver men's battle out them abroy's
# aith to be now, at codst prent, them follows;
# lean's hands? not the hand.
#
# AUTOLYCUS:
# Ase whon?' 'tis speak.
#
# DORCAS:
# Swear, preceriem, she s all may these her;
#  repirent
# But boy sometting, black; sir,
# Good bow; why before wiple's afform feOl blastition's
# sharnds, he manry.
#
# MOPSA:
# What falls of the great merry? To weathe,
# the queen
# or I
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 8500: 2.129028081893921
# Speech atten pacm a laonadien. Leon his imprincuy
# and with thy to thy sweet, and blood, to to give the coupfily
# Our heavens in Scepiress. I was we have loss?
#
# one:
# Not come and yet's crection; and sir, of like world for
# Stirat you ama's: live my prince with you, doth with
# heart. So, profess,
# In spright entation let somethion she met.
#
# Satis:
# Thou lors. My seeminess, your instrultes;
# Show too, power.
#
# LEONTES:
# Let your queens grower
# He like of his satabered hence upor; nor so appeave
# creels of ha
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 9000: 1.8926020860671997
# ence a boot
# Of your i weipt as a feet langing. Freading thee, as,
# Let me angela, 'fold good throng, then the live,
# And this such ded plainly have lave me to,
# whixe cildman in subsimied after petes:
# The earth.
#
# CLAUDIO:
# Here infit my wrad it tlamde.
#
# ELBOW:
# If it not love's, a he a have,
# If it noble and the hatix.
#
# CLAUDIO:
# Death.
#
# CLAUDIO:
# I am offence, my grieft in sure in duture
# As most a a you of that trat thinesher
# To yoniefa to lices weok anch conjest us
# yreedmentroon prove dield din.
#
# HERD
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 9500: 1.171002745628357
# ear,
# Trust fellow, for him, matter!
#
# ANGELO:
# By dishonomame, his truth; as,--
#
# ESCALUS:
# But my lord
# As office, like to should, and answer to so
# I trust love against our strange, shall call.
# Heavine undericed wey; and send every prace
# Fairs! Thou hasse for the entwauguitood.
#
# ISABELLA:
# Dirkings, forfely your processurity
# As love, madd, fitsted your swarguie.
#
# ISABELLA:
# Llony Upon you as is a bread,
# Upon the deal with yourself a must I
# look them hasth! the capory what I would
# In that migs' I wrong
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 10000: 1.0497668981552124
# nuse.
#
# PETRUCHIO:
# Such fortune and me see, old requence:
# And know my triby heard his signior well quame
# But are you that were shall hang his mouthba will bear
# To high and not not him a life, his father.
#
# PETRUCHIO:
# Od, have fit in good, Will news in depoit may?
#
# GREMIO:
# So is Lutentyless
# Is mook, some faulting not a rable, in throw more
# would go if I auth; good that ouve your gurance.
#
# HORTEYSSO:
# You see And tell him drench bortune will country,--
# I'll live'd and over more min woler. Gentleme lo
# --------------------------------------------------------------------------------

# %%
print('-' * 20)
print(generated_text)
print('-' * 20)

print('-' * 20)
sample_1 = model.sample(inputs[1])
print(sample_1)
print('-' * 20)

plt.plot(saved_loss)
plt.show()
# Out:
# --------------------
# you comes your face?
#
# PETRUCHIO:
# Broxs: we know a futh knan their life whom be
# And be with have ha'd. Her lipshant, sir, you like command.
# There to find this at hope in still shall hase
# And he would I wither ?m'n, improck and requill she in!
# 'Tis shrebust it for me send bi; sir, a kname in quarrel lips so so-skith
# An enviends, Peace, what of this compane.
#
# HORTENSIO:
# ferage he begin think  will not witl heaven?
#
# HORTENSIO:
# Yea. Since age of my heavent a byerfurog and pack'd
# Ge to him be and ray
# --------------------
# --------------------
# tandpost,
# Her in hold!
# This wind you to goes: that she may defiling biil;
# Is he a to tucy chargure!
#
# PETRUCHIO:
# Wrants chrunt Gramio?
# To, tike, see acquit nead, Jove
# As we, will that you like tongue ere, and the father,
# You good nock in Trumit, good follow!
#
# GRdMIO:
# Gremio, he
# 'ina; I woo well old eyes! Matcers, if I in God:
# Having I caned scording the chancit.
# Have so chee bett light can? O, dhen We please
# To me in the men and what well to so cold-radsen good
# clong furder would all maim, or pur
# --------------------

# %% [markdown]
# ### Next

# %% [markdown]
# The next cell loads a variant of the GPT-2 transformer.

# %%
model_id = 'openai-community/gpt2-large'
model = GPT2LMHeadModel.from_pretrained(model_id).to(device)
tokenizer = GPT2TokenizerFast.from_pretrained(model_id)

test = load_dataset('wikitext', 'wikitext-2-raw-v1', split='test')[:50]
encodings = tokenizer('\n\n'.join(test['text']), return_tensors='pt')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/733k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.36M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/657k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2513 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ### Exercise

# %% [markdown]
# What is the dimension of the GPT model which we are using (that is, the maximum length of a processable string)?

# %% [markdown]
# max lenght = 1024

# %%
print(model.__dict__)
# Out:
# {'training': False, '_parameters': OrderedDict(), '_buffers': OrderedDict(), '_non_persistent_buffers_set': set(), '_backward_pre_hooks': OrderedDict(), '_backward_hooks': OrderedDict(), '_is_full_backward_hook': None, '_forward_hooks': OrderedDict(), '_forward_hooks_with_kwargs': OrderedDict(), '_forward_hooks_always_called': OrderedDict(), '_forward_pre_hooks': OrderedDict(), '_forward_pre_hooks_with_kwargs': OrderedDict(), '_state_dict_hooks': OrderedDict(), '_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_post_hooks': OrderedDict(), '_modules': OrderedDict([('transformer', GPT2Model(
#   (wte): Embedding(50257, 1280)
#   (wpe): Embedding(1024, 1280)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-35): 36 x GPT2Block(
#       (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (act): NewGELUActivation()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
# )), ('lm_head', Linear(in_features=1280, out_features=50257, bias=False))]), 'config': GPT2Config {
#   "_name_or_path": "openai-community/gpt2-large",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1280,
#   "n_head": 20,
#   "n_inner": null,
#   "n_layer": 36,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }
# , 'name_or_path': 'openai-community/gpt2-large', 'warnings_issued': {}, 'generation_config': GenerationConfig {
#   "bos_token_id": 50256,
#   "eos_token_id": 50256
# }
# , '_keep_in_fp32_modules': None, 'model_parallel': False, 'device_map': None, '_is_hf_initialized': True}

# %% [markdown]
# ### Exercise

# %% [markdown]
# The code in the next cell computes the perplexity of a string generated by this model, where this string has a length higher than the model dimension. Run the code and take note of the obtained perplexity value. Is this procedure is in line with the technique?

# %%
max_length = model.config.n_positions
stride = 1024 # no overlap
seq_len = encodings.input_ids.size(1)

nlls = []
prev_end_loc = 0
for begin_loc in tqdm(range(0, seq_len, stride)):
    end_loc = min(begin_loc + max_length, seq_len)
    trg_len = end_loc - prev_end_loc
    input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100

    with torch.no_grad():
        outputs = model(input_ids, labels=target_ids)

        # loss is calculated using CrossEntropyLoss
        # which averages over valid labels
        # N.B. the model only calculates loss over trg_len - 1 labels, because
        # it internally shifts the labels to the left by 1.
        neg_log_likelihood = outputs.loss

    nlls.append(neg_log_likelihood)

    prev_end_loc = end_loc
    if end_loc == seq_len:
        break

ppl = torch.exp(torch.stack(nlls).mean())
print(ppl)
# Out:
#  67%|██████▋   | 2/3 [00:01<00:00,  1.63it/s]
# tensor(18.8686, device='cuda:0')

# %% [markdown]
# ### Exercise

# %% [markdown]
# Modify the previous cell so that perplexity is correctly estimated.

# %%
max_length = model.config.n_positions
stride = 512 # i would like to put 1
seq_len = encodings.input_ids.size(1)

nlls = []
prev_end_loc = 0
for begin_loc in tqdm(range(0, seq_len, stride)):
    end_loc = min(begin_loc + max_length, seq_len)
    trg_len = end_loc - prev_end_loc
    input_ids = encodings.input_ids[:, begin_loc:end_loc].to(device)
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100

    with torch.no_grad():
        outputs = model(input_ids, labels=target_ids)

        # loss is calculated using CrossEntropyLoss
        # which averages over valid labels
        # N.B. the model only calculates loss over trg_len - 1 labels, because
        # it internally shifts the labels to the left by 1.
        neg_log_likelihood = outputs.loss

    nlls.append(neg_log_likelihood)

    prev_end_loc = end_loc
    if end_loc == seq_len:
        break

ppl = torch.exp(torch.stack(nlls).mean())
print(ppl)

# %% [markdown]
# ### Next

# %% [markdown]
# We will not use anymore the GPT-2 model, thus we can free some RAM.

# %%
def clear_memory():
  gc.collect()
  torch.cuda.empty_cache()

del model
del tokenizer
clear_memory()

# %% [markdown]
# The next cell loads the Emotion dataset which we have used during the lecture.

# %%
emotions = load_dataset('emotion', trust_remote_code=True)
# Out:
# Downloading builder script:   0%|          | 0.00/3.97k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.28k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/592k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.9k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %% [markdown]
# ### Exercise

# %% [markdown]
# Select the first five examples in the training set, and show the corresponding tweet and encoded label. Peek into the training set object in order to figure out how to decode the numeric labels into the corresponding emotions.

# %%
emotions['train'].features["label"]
# Out:
# ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'], id=None)

# %%
i = 0
for element in emotions['train']:
  i = i + 1
  print("text: ", element["text"] , " label: ", element["label"] )
  if i == 10:
    tweet = element
  if i >= 10:
    break
# Out:
# text:  i didnt feel humiliated  label:  0
# text:  i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake  label:  0
# text:  im grabbing a minute to post i feel greedy wrong  label:  3
# text:  i am ever feeling nostalgic about the fireplace i will know that it is still on the property  label:  2
# text:  i am feeling grouchy  label:  3
# text:  ive been feeling a little burdened lately wasnt sure why that was  label:  0
# text:  ive been taking or milligrams or times recommended amount and ive fallen asleep a lot faster but i also feel like so funny  label:  5
# text:  i feel as confused about life as a teenager or as jaded as a year old man  label:  4
# text:  i have been with petronas for years i feel that petronas has performed well and made a huge profit  label:  1
# text:  i feel romantic too  label:  2

# %% [markdown]
# ### Next

# %% [markdown]
# We will use from now on the DistilBERT model, whose tokenizer is downloaded from Hugging Face in the next cell.

# %%
model_ckpt = 'distilbert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ### Exercise

# %% [markdown]
# Encode the 10-th tweet in the training set using the tokenizer associated to DistilBERT. Decode the obtained embeddings and check if some special tokens have been added.

# %%
tweet
encoded_text = tokenizer(tweet['text'], return_tensors='pt')
encoded_text
# Out:
# {'input_ids': tensor([[ 101, 1045, 2514, 6298, 2205,  102]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %% [markdown]
# ### Next

# %% [markdown]
# The following cell converts temporarily the display format of the training set, showing it as a Pandas DataFrame.

# %%
emotions.set_format(type='pandas')
df = emotions['train'][:]
df.head()

# %% [markdown]
# ### Exercise

# %% [markdown]
# Add to the previous DataFrame a `label_name` column containing the emotion names for each tween.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Show a bar plot for the absolute frequencies of each emotion in the train set.

# %% [markdown]
# ### Exercise

# %% [markdown]
# For each different emotion, show a box plot illustrating the corresponding distribution of tweet lengths (in terms of their number of words). If possible, align all these plots in a same graphic.

# %% [markdown]
# ### Next

# %% [markdown]
# The next cell resets the display form of the train set to its default, and defines a `tokenize` function which is then used to add to the train set also the tokenized versions of all tweets.

# %%
emotions.reset_format()

def tokenize(batch):
    return tokenizer(batch['text'], padding=True, truncation=True)

emotions_encoded = emotions.map(tokenize, batched=True, batch_size=None)

# %% [markdown]
# ### Exercise

# %% [markdown]
# Check that the train dataset has been augmented with the extracted encodings.

# %% [markdown]
# ### Next

# %% [markdown]
# The next cell loads the DistilBERT model and shows how to take an input, feed it to the model, and extract the states of the last hidden layer (that is, the learnt latent encoding for all tokens in the input).

# %%
model_ckpt = 'distilbert-base-uncased'
model = AutoModel.from_pretrained(model_ckpt).to(device)

# %%
text = 'this is a test'
inputs = tokenizer(text, return_tensors='pt')
print(f'Input tensor shape: {inputs['input_ids'].size()}')

inputs = {k:v.to(device) for k,v in inputs.items()}
with torch.no_grad():
    outputs = model(**inputs)
print(outputs)

print(f'Last hidden state tensor shape: {outputs.last_hidden_state.size()}')

# %% [markdown]
# ### Exercise

# %% [markdown]
# The following function accepts a batch of inputs and returns a dictionary associating the key `hidden_state` to the latent encoding of the first token of each input (that is, the `[CLS]` token). Fill in the missing parts, being sure to place the obtained tensors in the CPU and to subsequently convert them to numpy arrays.

# %%
def extract_hidden_states(batch):
    # Place model inputs on the GPU
    inputs = <FILL ME>
    # Extract last hidden states
    with torch.no_grad():
        <FILL ME>
    # Return vector for [CLS] token
    return {'hidden_state': <FILL ME>}

# %% [markdown]
# ### Next

# %% [markdown]
# The next cell applies the `extract_hidden_states` to the train set augmented with the tweet encondings. Note that it is necessary to convert to the internal PyTorch format the columns which have been added.

# %%
emotions_encoded.set_format('torch',
                            columns=['input_ids', 'attention_mask', 'label'])
emotions_hidden = emotions_encoded.map(extract_hidden_states, batched=True)

# %% [markdown]
# ### Exercise

# %% [markdown]
# Visualize the column names of the dataset obtained after `extract_hidden_states` has been applied, and check that a new column with the extracted latent encodings have been added.

# %% [markdown]
# ### Next

# %% [markdown]
# The following cell applies the UMAP dimensionality reduction to obtain a 2D compressed representation of the latent encodings.

# %%
# Scale features to [0,1] range
X_scaled = MinMaxScaler().fit_transform(X_train)
# Initialize and fit UMAP
mapper = UMAP(n_components=2, metric='cosine').fit(X_scaled)
# Create a DataFrame of 2D embeddings
df_emb = pd.DataFrame(mapper.embedding_, columns=['X', 'Y'])
df_emb['label'] = y_train
df_emb.head()

# %% [markdown]
# ### Exercise

# %% [markdown]
# Considering each emotion separately, show a graphic (for instance, an hexbin graph--check the matplotlib documentation for the details) that depicts how are distributed all the 2D points in `df_emb` which correspond to that emotion.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Use the data in `X_train` and `y_train` to train a logistic regression model, setting the maximum number of iterations to 3000. Compute the accuracy of the learnt model on the validation set that you extracted before and visualize the corresponding confusion matrix.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Repeat the previous exercise using another supervised ML model of your choice.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Attach a classification head to the previously loaded DistilBERT model, using the `AutoModelForSequenceClassification` class.

# %% [markdown]
# #### Exercise

# %% [markdown]
# While running the code for the previous exercise, you should have obtained a warning. Is this correct?

# %% [markdown]
# ### Next

# %% [markdown]
# The following cells define the objects which are needed in order to train the model created in the previous exercise.

# %%
batch_size = 64
logging_steps = len(emotions_encoded['train']) // batch_size
model_name = f'{model_ckpt}-finetuned-emotion'
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=2,
                                  learning_rate=2e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  evaluation_strategy='epoch',
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  log_level='error')

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {'accuracy': acc, 'f1': f1}

# %% [markdown]
# ### Exercise

# %% [markdown]
# Use the `Trainer` class in order to train the model we have created (hint: have a look at the official documentation, and if something is not correct you can see the answer in the slides of the lecture).

# %% [markdown]
# ### Exercise

# %% [markdown]
# Compute the performance metrics for the trained model, and show the corresponding confusion matrix, comparing it with the one of the model based on logistic regression.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Play with the data provided to `TrainingArguments` in order to slighlty modify the learning process.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Complete the following cell so that the BLEU score for the provided texts in `source` and `summary` is computed.

# %%
from datasets import load_metric

source = 'It is reported that on April, 23rd a lunar eclipse will be visible'
         ' between 10PM and 11PM in the surroundings of Athens.'
summary = 'A lunar eclipse will be visible around Athens during the night'
          ' of April, 23rd.'

<FILL ME>

# %% [markdown]
# #### Exercise

# %% [markdown]
# Repeat the previous exercise, now using `'Athens Athens Athens Athens Athens Athens'` as summary.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Compute the ROUGE score for the first summary. Note that the output is richer than with BLUE: for each of the variants of the ROUGE score, only select the `f1measure` value of the `mid` field.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Compute the BLUE score of the text generated in the last exercise using RNNs (you should have saved it in a `generated_text` variable). Note that the source is in this case the whole corpus, which is available in the `data` field of the `CustomDataset` object which you created.

# %% [markdown]
# ### Exercise

# %% [markdown]
# Download from Hugging Face any model for summarization and use it on a text of your choice (you can use, for instance, the example text provided in the card of the model you have downloaded). Compute the BLUE and ROUGE scores for the obtained summarization.
